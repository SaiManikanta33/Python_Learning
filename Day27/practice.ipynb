# %% [markdown]
# 💻 Practice Exercises
# Exercise 1
#
# Create a new virtual environment called:
#
# cyber_lab

# %%
Exercise 2

Activate the environment.

Install:

requests
pandas

# %% [markdown]
# Exercise 3
#
# Generate a requirements.txt file.

# %% [markdown]
# Exercise 4
#
# Deactivate the environment and activate it again.

# %% [markdown]
# Exercise 5
#
# Create the following project structure:
#
# python_lab/
# ├── src/
# ├── data/
# ├── logs/
# ├── tests/
# ├── README.md
# ├── requirements.txt
# └── .gitignore

# %% [markdown]
# 1. Open your terminal in             Python_Learning.
#
# 2. Create the main project folder:
#
# mkdir python_lab
# cd python_lab
# 3. Create the subfolders:
# mkdir src, data, logs, tests
# 4. Create the files:
# New-Item README.md, requirements.txt, .gitignore -ItemType File
# 5. Your structure will be:
# python_lab/
# ├── src/
# ├── data/
# ├── logs/
# ├── tests/
# ├── README.md
# ├── requirements.txt
# └── .gitignore
