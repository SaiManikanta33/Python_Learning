# %% [markdown]
# Exercise 1
#
# Create a Car class with:
#
# brand
# model
# year
#
# Print all details.

# %%
class car():
    pass
car1 = car()
car1.brand="BMW"
car1.model="M4"
car1.year = 2026

print(car1.brand)
print(car1.model)
print(car1.year)
# Out:
# BMW
# M4
# 2026

# %% [markdown]
# Exercise 2
#
# Create a Book class.
#
# Methods:
#
# display()
#
# Output:
#
# Book Name: Python Basics
# Author: John

# %%
class book():
    def __init__(self,bookname,author):
        self.bookname = bookname
        self.author = author
    def display(self):
        print(f"Book Name : {self.bookname}")
        print(f"Author : {self.author}")
books = book("Think Your Self","A person")
books.display()
# Out:
# Book Name : Think Your Self
# Author : A person

# %% [markdown]
# Create a Circle class.
#
# Method:
#
# area()
#
# Formula:
#
# πr²
#
# Use:
#
# import math

# %%
import math
class circle:
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2

# Example usage
c = circle(5)
print(f"Area of circle with radius 5: {c.area():.2f}")
# Out:
# Area of circle with radius 5: 78.54

# %% [markdown]
# Exercise 4
#
# Create an Employee class.
#
# Store:
#
# Name
# Salary
# Department
#
# Display all information.

# %%
class employee():
    def __init__(self,name,salary,dept):
        self.name = name
        self.salary = salary
        self.dept = dept
    def display():
        print(f"My name is {self.name} and my salary {self.salary} from department is {self.dept}")
Employee = employee("sai","24LPA","Security Analyst")
employee.display = display
Employee.display()
# Out:
# My name is sai and my salary 24LPA from department is Security Analyst

# %% [markdown]
# Exercise 5
#
# Create a BankAccount class.
#
# Methods:
#
# deposit()
# withdraw()
# show_balance()
#
# Example:
#
# Balance = 5000
#
# Deposit = 1000
#
# Balance = 6000

# %%
class BankAccount():
    def __init__(self, balance):
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited: {amount}")
        print(f"Balance: {self.balance}")
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawn: {amount}")
            print(f"Balance: {self.balance}")
        else:
            print("Insufficient balance")
    
    def show_balance(self):
        print(f"Current Balance: {self.balance}")

# Create instance and use methods
account = BankAccount(5000)
account.deposit(1000)
account.withdraw(500)
account.show_balance()
# Out:
# Deposited: 1000
# Balance: 6000
# Withdrawn: 500
# Balance: 5500
# Current Balance: 5500
