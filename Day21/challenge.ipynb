# %% [markdown]
# 🧩 Mini Project
# Multithreaded Port Scanner
#
# Use only on systems you own or have permission to scan.

# %%
import socket
from concurrent.futures import ThreadPoolExecutor

host = "192.168.2.11"

def scan(port):
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(1)

    if sock.connect_ex((host, port)) == 0:
        print(f"Port {port}: OPEN")

    sock.close()

ports = range(20, 101)

with ThreadPoolExecutor(max_workers=20) as executor:
    executor.map(scan, ports)
    
with open("scan_results.txt","w")as file:
    print(file.write(f"ports{port} open"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      18     executor.map(scan, ports)
#      20 with open("scan_results.txt","w")as file:
# ---> 21     print(file.write(ports))
#
# TypeError: write() argument must be str, not range
