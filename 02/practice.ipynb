# %% [markdown]
# Exercise 1
#
# Take two numbers and print all arithmetic operations.

# %%
a=10
b=5
print(a+b)
print(a*b)
print(a-b)
print(a/b)
print(a**b)
print(a//b)
print(a%b)
# Out:
# 15
# 50
# 5
# 2.0
# 100000
# 2
# 0

# %% [markdown]
# Excercise 2
#
# Take your name and print:
#
# Uppercase
# Lowercase
# Length
# Reverse

# %%
name="Sai manikanta"
print(name.upper())
print(name.lower())
print(len(name))
print(name[::-1])
# Out:
# SAI MANIKANTA
# sai manikanta
# 13
# atnakinam iaS

# %% [markdown]
# Excercise 3
#
# Take your age as input and print your age after 10 years.

# %%
age=int(input("Age: "))
print("After 10 years your age will be: ",age+10)
# Out:
# After 10 years your age will be:  29

# %% [markdown]
# Exercise 4
#
# Take your first and last name separately and print your full name using an f-string.

# %%
fname=input("Enter first name:")
lname=input("Enter last name:")
print(f"{fname} {lname}")
# Out:
# sai manikanta

# %% [markdown]
# Exercise 5
#
# Take a sentence from the user and print:
#
# -Total characters
# -First character
# -Last character
# -Sentence in uppercase

# %%
name=input("Enter sentence: ")
print(len(name))
print(name[1])
print(name[-1])
print(name.upper())
# Out:
# 3
# a
# i
# SAI
