# %% [markdown]
# 🛡️ Cybersecurity Practice
#
# Build an Authenticated API Health Monitor that:
#
# Reads its token from .env
# Checks multiple authorized service endpoints
# Reports UP, UNAUTHORIZED, FORBIDDEN, RATE LIMITED, or DOWN
# Writes results to a log file
# Never stores the token in the log
#
# Example output:
#
# Authentication API  → UP
# Logging API         → UNAUTHORIZED
# Threat Intel API    → RATE LIMITED
