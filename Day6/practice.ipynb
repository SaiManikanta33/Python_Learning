# %% [markdown]
# 💻 Practice Exercises
# Exercise 1
#
# Use the math module to print:
#
# Square root of 144
# Value of π
# Factorial of 6

# %%
import math
print(math.sqrt(144))
print(math.pi)
print(math.factorial(6))
# Out:
# 12.0
# 3.141592653589793
# 720

# %% [markdown]
# Exercise 2
#
# Generate:
#
# -A random number between 1 and 100
# -A random programming language from a list

# %%
import random
print(random.randint(1, 100))
print(random.choice(["python","Java","C","Linux"]))
# Out:
# 1
# python

# %% [markdown]
# Exercise 3
#
# Display:
#
# -Current date
# -Current time
# -Current year

# %%
from datetime import datetime
n=datetime.now()
print(n)
print(n.year)
print(n.day)
print(n.month)
print(n.hour)
print(n.tzinfo)
# Out:
# 2026-07-11 14:57:28.200441
# 2026
# 11
# 7
# 14
# None

# %% [markdown]
# Exercise 4
#
# Print:
#
# -Current working directory
# -List all files in the current directory

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\SAI MANIKANTA\Python_Learning\Day6
# ['Modules.py', 'packages', 'packages.md', 'practice.ipynb', '__pycache__']

# %% [markdown]
# Exercise 5
#
# Create your own module named operations.py containing:
#
# add()
# subtract()
# multiply()
# divide()
#
# Import it into another Python file and test all functions.
#
#
#
#
#
# the operations.py is created in another folder because it can access by using import

# %%
import operations
print(operations.add(10,20))

print(operations.multiply(5,20))
print(operations.add(10, 20))
print(operations.multiply(5, 20))
print(operations.divide(20, 10))
print(operations.subtract(20,10))
# Out:
# 30
# 100
# 30
# 100
# 2.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 8
#       6 print(operations.multiply(5, 20))
#       7 print(operations.divide(20, 10))
# ----> 8 print(operations.subtract(20, 10))
#       9 print(operations.subtract(20,10))
#
# AttributeError: module 'operations' has no attribute 'subtract'
