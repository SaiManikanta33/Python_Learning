# %% [markdown]
# Exercise 1
#
# Create a CLI tool that adds two numbers.
#
# Example:
#
# python calculator.py --a 10 --b 20
#
# Output:
#
# 30

# %%
import argparse
parser = argparse.ArgumentParser()
parser.add_argument("--a",type=int)
parser.add_argument("--b",type=int)
args = parser.parse_args()

if args.square:
    print(args.square + b)

# %% [markdown]
# Exercise 2
#
# Create a JSON file storing:
#
# -Name
# -Age
# -Branch
# -Skills
#
# Read the file and print all values.

# %%
import json
college={
    "Name":"Sai",
    "Age":19,
    "Branch":"CSC",
    "Skills":"Blue Team"
}
with open("Day18/college.json","w")as file:
    json.dump(college,file,indent=4)

# %% [markdown]
# Reading

# %%
import json
with open("college.json","r")as file:
    data = json.load(file)
print(data["Name"])
print(data["Age"])
print(data["Branch"])
print(data["Skills"])
# Out:
# Sai
# 19
# CSC
