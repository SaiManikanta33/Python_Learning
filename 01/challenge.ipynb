# %%
#To create a program that asks:
    -Name
    -Age
    -College
    -Branch

# %%
name=input("Name:")
age=int(input("Age:"))
college=input("College:")
branch=input("Branch:")
print("----- Student Details ------")
print("Name:",name)
print("Age:",age)
print("College:",college)
print("Branch:",branch)
# Out:
# ----- Student Details ------
# Name: sa
# Age: 19
# College: Raghu Engeneering College
# Branch: Cyber Securit
