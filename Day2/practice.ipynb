# %%
a=10
b=5
print(a+b)
print(a*b)
print(a-b)
print(a/b)
print(a**b)
print(a//b)
print(a%b)
# Out:
# 15
# 50
# 5
# 2.0
# 100000
# 2
# 0

# %%
name="Sai manikanta"
print(name.upper())
print(name.lower())
print(len(name))
print(name.reverce())
